# %% [markdown]
# ## New York Time Article Search API

# %%
import pandas as pd

# %%
# df_token = pd.read_excel('api_token.xlsx')

# %%
# Replace with your token
token = df_token['TOKEN'][0]

# %%
import requests
import json

# %%
# establish the 'get' request to url with the selected category and include your personal token
response = requests.get(f'https://api.nytimes.com/svc/search/v2/articlesearch.json? \
                         q=election&api-key={token}')

# %%
## check the API response status
response.status_code
# Out:
# 200

# %%
response_json = response.json()

# %%
# review the first article
response_json['response']['docs'][0]
# Out:
# {'abstract': 'Philip Wolfe makes his New York Times Crossword debut.',
#  'web_url': 'https://www.nytimes.com/2022/07/06/crosswords/daily-puzzle-2022-07-07.html',
#  'snippet': 'Philip Wolfe makes his New York Times Crossword debut.',
#  'lead_paragraph': 'THURSDAY PUZZLE — There are certain pastimes that make it easy for people to fall down a rabbit hole. When I take up a new hobby, I find myself reading everything I can get my hands on about it, and, more often than not, that research will lead me to try something related. This is why I have so many half-finished knitting projects strewn about the house.',
#  'source': 'The New York Times',
#  'multimedia': [{'rank': 0,
#    'subtype': 'xlarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/07/07/crosswords/07wordplay-rabbits/07wordplay-rabbits-articleLarge.jpg',
#    'height': 430,
#    'width': 600,
# ...

# %%
# save the article to a json file > JSON pretty format to view
with open('sample_article,json','w') as f:
    json.dump(response_json['response']['docs'][0],f)

# %%
# save all 10 article from response into 10 seperate JSON file
for index,art in enumerate(response_json['response']['docs']):
    with open(f'article_{index}.json', 'w') as f:
        json.dump(art,f)

# %%
# %ls
# Out:
# API.ipynb
# Class 1 practice.ipynb
# Class10_Project1_EDA_Continue.ipynb
# Class10_Project1_EDA_DataPreproc_Continue.ipynb
# Class11 Model Training and Tuning.ipynb
# Class13_Python OOD Practice.ipynb
# Class2_DataStructure_Numpy_Pandas.ipynb
# Class3_EDA and Visualization.ipynb
# Class4_Data_Preprocessing.ipynb
# Class5_Data_Preprocessing_cont.ipynb
# Class7_Q&A.ipynb
# Class9_Project1_EDA_DataPreproc.ipynb
# Minions: The Rise of Gru.json
# OOD.ipynb
# OOD_PRACTICE.py
# Project1_EDA.ipynb
# Q&A.ipynb
# Shape.py
# Untitled.ipynb
# __pycache__/
# api_token.xlsx
# article_0.json
# article_1.json
# article_2.json
# article_3.json
# article_4.json
# article_5.json
# article_6.json
# article_7.json
# article_8.json
# article_9.json
# sample_article,json
# sample_article.json
# the godfather.json
